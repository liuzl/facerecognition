# %%
import face_recognition
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
def findFace(file_name):
    image = face_recognition.load_image_file(file_name)
    face_locations = face_recognition.face_locations(image)
    print("I found {} face(s) in this photograph.".format(len(face_locations)))
    
    images = []
    for face_location in face_locations:

        # Print the location of each face in this image
        top, right, bottom, left = face_location
        print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

        # You can access the actual face itself like this:
        face_image = image[top:bottom, left:right]
        pil_image = Image.fromarray(face_image)
        #pil_image.show()
        #plt.imshow(np.asarray(pil_image))
        images.append(pil_image)
    return images

# %%
def plot_images(images):
    plt.figure(figsize=(20,10))
    columns = 5
    for i, image in enumerate(images):
        plt.subplot(len(images) / columns + 1, columns, i + 1)
        plt.imshow(image)

# %%
plot_images(findFace("images/einstein_godel.jpg"))
# Out:
# I found 2 face(s) in this photograph.
# A face is located at pixel location Top: 86, Left: 354, Bottom: 176, Right: 444
# A face is located at pixel location Top: 86, Left: 155, Bottom: 176, Right: 245

# %%
plot_images(findFace("images/scientists.jpg"))
# Out:
# I found 16 face(s) in this photograph.
# A face is located at pixel location Top: 182, Left: 517, Bottom: 218, Right: 553
# A face is located at pixel location Top: 158, Left: 249, Bottom: 194, Right: 285
# A face is located at pixel location Top: 194, Left: 201, Bottom: 230, Right: 237
# A face is located at pixel location Top: 158, Left: 353, Bottom: 194, Right: 389
# A face is located at pixel location Top: 194, Left: 405, Bottom: 230, Right: 441
# A face is located at pixel location Top: 158, Left: 729, Bottom: 194, Right: 765
# A face is located at pixel location Top: 190, Left: 849, Bottom: 226, Right: 885
# A face is located at pixel location Top: 94, Left: 657, Bottom: 130, Right: 693
# A face is located at pixel location Top: 162, Left: 817, Bottom: 198, Right: 853
# A face is located at pixel location Top: 150, Left: 545, Bottom: 186, Right: 581
# A face is located at pixel location Top: 190, Left: 105, Bottom: 226, Right: 141
# A face is located at pixel location Top: 186, Left: 781, Bottom: 222, Right: 817
# A face is located at pixel location Top: 170, Left: 161, Bottom: 206, Right: 197
# A face is located at pixel location Top: 190, Left: 297, Bottom: 226, Right: 333
# A face is located at pixel location Top: 182, Left: 677, Bottom: 218, Right: 713
# A face is located at pixel location Top: 94, Left: 821, Bottom: 130, Right: 857

# %%
plot_images(findFace("images/IMG_1127.jpg"))
# Out:
# I found 2 face(s) in this photograph.
# A face is located at pixel location Top: 345, Left: 593, Bottom: 531, Right: 778
# A face is located at pixel location Top: 171, Left: 260, Bottom: 439, Right: 527
